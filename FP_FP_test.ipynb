# %% [markdown]
# <a href="https://colab.research.google.com/github/pritampanda15/AutodockGPU/blob/main/FP_FP_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit-pypi
# !git clone https://MHRasmussen@github.com/jensengroup/FP_RF_XAI.git

# !mv FP_RF_XAI/* .
# Out:
# ...
# fatal: destination path 'FP_RF_XAI' already exists and is not an empty directory.
# mv: cannot stat 'FP_RF_XAI/*': No such file or directory

# %%
import pickle

from rdkit import Chem
from fp_xai import get_weights_for_visualization, get_contour_image

# %%
# !wget https://sid.erda.dk/share_redirect/hcpheu2AFL
m = pickle.load(open("/content/hcpheu2AFL", 'rb'))
# Out:
# --2022-03-15 13:05:25--  https://sid.erda.dk/share_redirect/hcpheu2AFL
# Resolving sid.erda.dk (sid.erda.dk)... 130.225.104.13
# Connecting to sid.erda.dk (sid.erda.dk)|130.225.104.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 680105126 (649M)
# Saving to: ‘hcpheu2AFL.1’
#
# hcpheu2AFL.1        100%[===================>] 648.60M  19.6MB/s    in 35s
#
# 2022-03-15 13:06:01 (18.5 MB/s) - ‘hcpheu2AFL.1’ saved [680105126/680105126]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.23.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,
# ...

# %%
smiles = "CC[NH+](CC)[C@@H]1CCN(C(=O)N[C@@H]2CCCC2)C1"
mol = Chem.MolFromSmiles(smiles)
ml_weights, atom_weights, fpa_weights = get_weights_for_visualization(mol, m, radius=2, n_bits=2048)
fig = get_contour_image(mol, fpa_weights)
#fig.savefig("ml_weights_example.pdf", bbox_inches='tight')
# Out:
# ml weights: sign problem detected
# FPA weights: sign problem detected
